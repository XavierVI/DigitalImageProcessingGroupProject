# %%
from alert_system.utils.model_loader import load_detection_model, load_llm_model
from alert_system.data_stream.dataset import VideoDataset


data_root = "../data/reddit_dashcam_videos/"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from alert_system.utils.model_loader import load_detection_model, load_llm_model
#       2 from alert_system.data_stream.dataset import VideoDataset
#       3
#       4
#
# ModuleNotFoundError: No module named 'alert_system'

# %% [markdown]
# ## Set Up Data and Models

# %%
detection_model = load_detection_model()
llm_model = load_llm_model()

dataset = VideoDataset(data_root)
